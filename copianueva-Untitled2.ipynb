# %%
ls -al
# Out:
# total 64
# drwxr-xr-x 10 vagrant vagrant 4096 Sep 11 09:59 .
# drwxr-xr-x  3 root    root    4096 Feb 23  2018 ..
# -rw-------  1 vagrant vagrant   31 Sep  4 09:43 .bash_history
# -rw-r--r--  1 vagrant vagrant  220 Feb 23  2018 .bash_logout
# -rw-r--r--  1 vagrant vagrant 3713 Apr 22 14:20 .bashrc
# drwx------  3 vagrant vagrant 4096 Apr 22 14:28 .cache
# drwxr-xr-x  2 vagrant vagrant 4096 Sep 11 09:57 .ipynb_checkpoints
# drwxr-xr-x  5 vagrant vagrant 4096 Sep 11 09:57 .ipython
# drwx------  6 vagrant vagrant 4096 Sep 11 09:35 .local
# drwxr-xr-x  2 vagrant vagrant 4096 Feb 23  2018 .nano
# -rw-r--r--  1 vagrant vagrant  675 Feb 23  2018 .profile
# drwxrwxrwx  1 vagrant vagrant 4096 Aug 30 12:45 proyectos
# drwxr-xr-x 13 vagrant vagrant 4096 Apr 22 14:20 .pyenv
# drwx------  2 vagrant vagrant 4096 Sep  4 09:07 .ssh
# -rw-r--r--  1 vagrant vagrant  410 Sep 11 09:59 Untitled.ipynb
# -rw-r--r--  1 vagrant vagrant  180 Feb 23  2018 .wget-hsts

# %% [markdown]
# El parametro *-l* nos muestra en una lista los archivos y añade información del archivo o directorio mostrado (permisos, a quien pertenece y grupo al que pertenece y grupo al que pertenece, tamaño en disco, fecha de creación o modificación.
#
# NOTA: Podemos diferenciar entre un archivo y directorio por la inicial mostrada (*drwxr-xr-x* directorio *-rw-r--r--* archivo).
#
# El parametro *-h* nos muestra en un formato mas amigable human readable el tamaño de los archivos.

# %% [markdown]
# # Comando basicos de Linux
#
# Aqui vamos a documentar algunos comandos basicos de Linux
#
# Comando **ls**:
# Nos muestra en pantalla un listado de archivos del directorio donde estemos
# posicionados o bien recibe un parametro de la ruta a listar.

# %%
ls
# Out:
# proyectos  Untitled.ipynb

# %%
ls -a /home/vagrant
# Out:
# .              .bashrc             .jupyter  proyectos       .wget-hsts
# ..             .cache              .local    .pyenv
# .bash_history  .ipynb_checkpoints  .nano     .ssh
# .bash_logout   .ipython            .profile  Untitled.ipynb

# %% [markdown]
# El parametro *-a* muestra todos los archivos (ocultos y no ocultos) este parametro se puede mezclar con otros parametros.

# %%
ls /usr/bin
# Out:
# [                                   mapscrn
# 2to3                                mawk
# 2to3-2.7                            mcookie
# 2to3-3.5                            md5sum
# addpart                             md5sum.textutils
# addr2line                           mesg
# appres                              messages
# apropos                             messages.mailutils
# apt                                 migrate-pubring-from-classic-gpg
# apt-cache                           mimeview
# apt-cdrom                           mkfifo
# apt-config                          mk_modmap
# apt-extracttemplates                movemail
# apt-ftparchive                      movemail.mailutils
# apt-get                             mpicalc
# apt-key                             mtrace
# apt-listchanges                     munchlist
# apt-mark                            namei
# apt-sortpkgs                        nawk
# ar                                  ncal
# arch                                ncurses5-config
# as                                  neqn
# awk                                 newaliases
# b2sum                               newgrp
# base32                              ngettext
# base64                              nice
# basename                            nl
# bashbug                             nm
# bootctl                             nohup
# bsd-from                            nproc
# bsd-write                           nroff
# bugpoint                            nsenter
# bugpoint-3.8                        nslookup
# buildhash                           nspr-config
# busctl                              nss-config
# c++                                 nstat
# c2ph                                nsupdate
# c89                                 numfmt
# c89-gcc                             obj2yaml
# c99                                 obj2yaml-3.8
# c99-gcc                             objcopy
# cal                                 objdump
# calendar                            od
# captoinfo                           on_ac_power
# catchsegv                           openssl
# catman                              opt
# cc                                  opt-3.8
# c++filt                             os-prober
# chage                               pager
# chardet3                            partx
# chardetect3                         passwd
# chattr                              paste
# chcon                               patch
# chfn                                pathchk
# chrt                                pcimodules
# chsh                                pdb
# ckbcomp                             pdb2.7
# cksum                               pdb3
# clear                               pdb3.5
# clear_console                       peekfd
# cmp                                 perf
# codepage                            perl
# col                                 perl5.24.1
# colcrt                              perl5.24-x86_64-linux-gnu
# colrm                               perlbug
# column                              perldoc
# comm                                perlivp
# compose                             perlthanks
# corelist                            pg
# cpan                                pgrep
# cpan5.24-x86_64-linux-gnu           pic
# cpp                                 pico
# cpp-6                               piconv
# c_rehash                            pinentry
# crontab                             pinentry-curses
# csplit                              pinky
# ctstat                              pip
# curl                                pip2
# cut                                 pip3
# dbus-cleanup-sockets                pkg-config
# dbus-daemon                         pkgdata
# dbus-monitor                        pkill
# dbus-run-session                    pl2pm
# dbus-send                           pldd
# dbus-update-activation-environment  pmap
# dbus-uuidgen                        pngfix
# deallocvt                           png-fix-itxt
# debconf                             pod2html
# debconf-apt-progress                pod2man
# debconf-communicate                 pod2text
# debconf-copydb                      pod2usage
# debconf-escape                      podchecker
# debconf-set-selections              podselect
# debconf-show                        pr
# deb-systemd-helper                  preconv
# deb-systemd-invoke                  prename
# defmt-c                             print
# defmt-sh                            printenv
# delpart                             printerbanner
# derb                                printf
# dh_bash-completion                  prlimit
# dh_installxmlcatalogs               prove
# dh_pypy                             prtstat
# dh_python2                          psfaddtable
# dh_python3                          psfgettable
# diff                                psfstriptable
# diff3                               psfxtable
# dig                                 pstree
# dircolors                           pstree.x11
# dirname                             pstruct
# discover-config                     ptar
# dotlock                             ptardiff
# dotlockfile                         ptargrep
# dotlock.mailutils                   ptx
# dpkg                                pwdx
# dpkg-architecture                   py3clean
# dpkg-buildflags                     py3compile
# dpkg-buildpackage                   py3versions
# dpkg-checkbuilddeps                 pybuild
# dpkg-deb                            pyclean
# dpkg-distaddfile                    pycompile
# dpkg-divert                         pydoc
# dpkg-genbuildinfo                   pydoc2.7
# dpkg-genchanges                     pydoc3
# dpkg-gencontrol                     pydoc3.5
# dpkg-gensymbols                     pygettext
# dpkg-maintscript-helper             pygettext2.7
# dpkg-mergechangelogs                pygettext3
# dpkg-name                           pygettext3.5
# dpkg-parsechangelog                 python
# dpkg-query                          python2
# dpkg-scanpackages                   python2.7
# dpkg-scansources                    python2.7-config
# dpkg-shlibdeps                      python2-config
# dpkg-source                         python3
# dpkg-split                          python3.5
# dpkg-statoverride                   python3.5-config
# dpkg-trigger                        python3.5m
# dpkg-vendor                         python3.5m-config
# du                                  python3-config
# dumpkeys                            python3m
# dumpsexp                            python3m-config
# dwp                                 python-config
# easy_install                        pyversions
# easy_install3                       querybts
# edit                                ranlib
# editor                              rcp
# editres                             readelf
# eject                               readmsg
# elfedit                             readmsg.mailutils
# enc2xs                              realpath
# encguess                            rename
# env                                 rename.ul
# envsubst                            renice
# eqn                                 reportbug
# ex                                  report-hw
# expand                              reset
# expiry                              resize
# expr                                resizecons
# factor                              resizepart
# faillog                             rev
# faked-sysv                          rgrep
# faked-tcp                           rlogin
# fakeroot                            routef
# fakeroot-sysv                       routel
# fakeroot-tcp                        rpcgen
# fallocate                           rsh
# file                                rsync
# file-rename                         rtstat
# find                                runcon
# findaffix                           run-mailcap
# flock                               rview
# fmt                                 savelog
# fold                                scp
# free                                screendump
# freetype-config                     script
# frm                                 scriptreplay
# frm.mailutils                       sdiff
# from                                see
# from.mailutils                      select-default-iwrap
# g++                                 select-editor
# g++-6                               sensible-browser
# gcc                                 sensible-editor
# gcc-6                               sensible-pager
# gcc-ar                              seq
# gcc-ar-6                            setarch
# gcc-nm                              setkeycodes
# gcc-nm-6                            setleds
# gcc-ranlib                          setlogcons
# gcc-ranlib-6                        setmetamode
# gcov                                setpci
# gcov-6                              setsid
# gcov-dump                           setterm
# gcov-dump-6                         setvtrgb
# gcov-tool                           sftp
# gcov-tool-6                         sg
# genbrk                              sha1sum
# gencat                              sha224sum
# gencfu                              sha256sum
# gencnval                            sha384sum
# gendict                             sha512sum
# genrb                               shasum
# geqn                                showconsolefont
# getconf                             showkey
# getent                              shred
# getkeycodes                         shuf
# getopt                              sieve
# gettext                             size
# gettext.sh                          skill
# git                                 slabtop
# git-receive-pack                    slogin
# git-shell                           snice
# git-upload-archive                  soelim
# git-upload-pack                     sort
# gold                                sotruss
# gpasswd                             splain
# gpg                                 split
# gpg-agent                           splitfont
# gpgconf                             sprof
# gpg-connect-agent                   sq
# gpg-error                           ssh
# gpg-error-config                    ssh-add
# gpgparsemail                        ssh-agent
# gpgsplit                            ssh-argv0
# gpgv                                ssh-copy-id
# gpg-zip                             ssh-keygen
# gpic                                ssh-keyscan
# gprof                               stat
# groff                               stdbuf
# grog                                strings
# grops                               strip
# grotty                              sudo
# groups                              sudoedit
# grub-editenv                        sudoreplay
# grub-file                           sum
# grub-fstest                         symcryptrun
# grub-glue-efi                       systemd-analyze
# grub-kbdcomp                        systemd-cat
# grub-menulst2cfg                    systemd-cgls
# grub-mkfont                         systemd-cgtop
# grub-mkimage                        systemd-delta
# grub-mklayout                       systemd-detect-virt
# grub-mknetdir                       systemd-mount
# grub-mkpasswd-pbkdf2                systemd-path
# grub-mkrelpath                      systemd-resolve
# grub-mkrescue                       systemd-run
# grub-mkstandalone                   systemd-socket-activate
# grub-mount                          systemd-stdio-bridge
# grub-ntldr-img                      tabs
# grub-render-label                   tac
# grub-script-check                   tail
# grub-syslinux2cfg                   tasksel
# gtbl                                taskset
# h2ph                                tbl
# h2xs                                tclsh
# hd                                  tclsh8.6
# head                                tcltk-depends
# helpztags                           tee
# hexdump                             telnet
# hmac256                             telnet.netkit
# host                                test
# hostid                              tic
# hostnamectl                         timedatectl
# htop                                timeout
# i386                                tload
# icombine                            toe
# iconv                               top
# icu-config                          touch
# icuinfo                             tput
# id                                  tr
# ijoin                               traceproto
# infocmp                             traceproto.db
# infotocap                           traceroute
# install                             traceroute6
# instmodsh                           traceroute6.db
# ionice                              traceroute.db
# ipcmk                               traceroute-nanog
# ipcrm                               troff
# ipcs                                truncate
# iptables-xml                        tryaffix
# ischroot                            tset
# ispell                              tsort
# ispell-wrapper                      tty
# join                                tzselect
# json_pp                             ucf
# kbdinfo                             ucfq
# kbxutil                             ucfr
# kernel-install                      uconv
# killall                             ul
# koi8rxterm                          unexpand
# last                                unicode_stop
# lastb                               uniq
# lastlog                             unlink
# lcf                                 unlzma
# ld                                  unmkinitramfs
# ld.bfd                              unshare
# ldd                                 unsq
# ld.gold                             unxz
# less                                update-alternatives
# lessecho                            update-mime-database
# lessfile                            update-mime-database.real
# lesskey                             uptime
# lesspipe                            usb-devices
# lexgrog                             usbhid-dump
# lft                                 users
# lft.db                              utmpdump
# libgcrypt-config                    uxterm
# libnetcfg                           VBoxClient
# libpng16-config                     VBoxControl
# libpng-config                       verify-uselistorder
# line                                verify-uselistorder-3.8
# link                                vi
# linux32                             view
# linux64                             viewres
# linux-boot-prober                   vim.tiny
# linux-check-removal                 vmstat
# linux-update-symlinks               volname
# linux-version                       w
# listres                             wall
# llc                                 watch
# llc-3.8                             watchgnupg
# lli                                 wc
# lli-3.8                             wget
# llvm-ar                             whatis
# llvm-ar-3.8                         whereis
# llvm-as                             which
# llvm-as-3.8                         whiptail
# llvm-bcanalyzer                     who
# llvm-bcanalyzer-3.8                 whoami
# llvm-config                         wish
# llvm-config-3.8                     wish8.6
# llvm-cov                            w.procps
# llvm-cov-3.8                        write
# llvm-c-test-3.8                     X11
# llvm-cxxdump-3.8                    x86_64
# llvm-diff                           x86_64-linux-gnu-addr2line
# llvm-diff-3.8                       x86_64-linux-gnu-ar
# llvm-dis                            x86_64-linux-gnu-as
# llvm-dis-3.8                        x86_64-linux-gnu-c++filt
# llvm-dsymutil-3.8                   x86_64-linux-gnu-cpp
# llvm-dwarfdump                      x86_64-linux-gnu-cpp-6
# llvm-dwarfdump-3.8                  x86_64-linux-gnu-dwp
# llvm-dwp-3.8                        x86_64-linux-gnu-elfedit
# llvm-extract                        x86_64-linux-gnu-g++
# llvm-extract-3.8                    x86_64-linux-gnu-g++-6
# llvm-lib-3.8                        x86_64-linux-gnu-gcc
# llvm-link                           x86_64-linux-gnu-gcc-6
# llvm-link-3.8                       x86_64-linux-gnu-gcc-ar
# llvm-lto-3.8                        x86_64-linux-gnu-gcc-ar-6
# llvm-mc                             x86_64-linux-gnu-gcc-nm
# llvm-mc-3.8                         x86_64-linux-gnu-gcc-nm-6
# llvm-mcmarkup-3.8                   x86_64-linux-gnu-gcc-ranlib
# llvm-nm                             x86_64-linux-gnu-gcc-ranlib-6
# llvm-nm-3.8                         x86_64-linux-gnu-gcov
# llvm-objdump                        x86_64-linux-gnu-gcov-6
# llvm-objdump-3.8                    x86_64-linux-gnu-gcov-dump
# llvm-pdbdump-3.8                    x86_64-linux-gnu-gcov-dump-6
# llvm-PerfectShuffle-3.8             x86_64-linux-gnu-gcov-tool
# llvm-profdata                       x86_64-linux-gnu-gcov-tool-6
# llvm-profdata-3.8                   x86_64-linux-gnu-gprof
# llvm-ranlib                         x86_64-linux-gnu-ld
# llvm-ranlib-3.8                     x86_64-linux-gnu-ld.bfd
# llvm-readobj-3.8                    x86_64-linux-gnu-ld.gold
# llvm-rtdyld                         x86_64-linux-gnu-nm
# llvm-rtdyld-3.8                     x86_64-linux-gnu-objcopy
# llvm-size                           x86_64-linux-gnu-objdump
# llvm-size-3.8                       x86_64-linux-gnu-pkg-config
# llvm-split-3.8                      x86_64-linux-gnu-python2.7-config
# llvm-stress-3.8                     x86_64-linux-gnu-python3.5-config
# llvm-symbolizer                     x86_64-linux-gnu-python3.5m-config
# llvm-symbolizer-3.8                 x86_64-linux-gnu-python3-config
# llvm-tblgen                         x86_64-linux-gnu-python3m-config
# llvm-tblgen-3.8                     x86_64-linux-gnu-python-config
# lnstat                              x86_64-linux-gnu-ranlib
# loadkeys                            x86_64-linux-gnu-readelf
# loadunimap                          x86_64-linux-gnu-size
# locale                              x86_64-linux-gnu-strings
# localectl                           x86_64-linux-gnu-strip
# localedef                           x86_64-pc-linux-gnu-pkg-config
# logger                              xargs
# logname                             xauth
# look                                xdg-user-dir
# lorder                              xdg-user-dirs-update
# lsattr                              xdpyinfo
# lsb_release                         xdriinfo
# lscpu                               xev
# lsinitramfs                         xfd
# lsipc                               xfontsel
# lslocks                             xkill
# lslogins                            xlsatoms
# lsns                                xlsclients
# lsof                                xlsfonts
# lspci                               xmessage
# lspgpot                             xml2-config
# lsusb                               xmlsec1-config
# luit                                xprop
# lxterm                              xslt-config
# lzcat                               xsubpp
# lzcmp                               xterm
# lzdiff                              x-terminal-emulator
# lzegrep                             xvinfo
# lzfgrep                             xwininfo
# lzgrep                              xxd
# lzless                              xz
# lzma                                xzcat
# lzmainfo                            xzcmp
# lzmore                              xzdiff
# mail                                xzegrep
# mail.mailutils                      xzfgrep
# mailq                               xzgrep
# mailutils                           xzless
# mailx                               xzmore
# make                                yaml2obj
# makeconv                            yaml2obj-3.8
# make-first-existing-target          yes
# man                                 zdump
# mandb                               zipdetails
# manpath

# %% [markdown]
# # Copia archivos y directorios
#
# Para copiar archivos y directorios en linux podemos usar el comando *cp*.
#
# El primer parametro es el nombre de archivo o directorio de origen, y el segundo parametro es el archivo o ruta donde se creara la copia de este.

# %%
ls
# Out:
# proyectos  Untitled.ipynb

# %%
cp Untitled.ipynb copia-Untitled.ipynb

# %%
mkdir copiame
# Out:
# mkdir: cannot create directory ‘copiame’: File exists
# : 1

# %%
cp Untitled.
